# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv("Prep-CustomerDemographic.csv")

# %%
cont_value_data = raw_data[['past_3_years_bike_related_purchases', 'tenure', 'Age']]

# %%
corr_mat = cont_value_data.corr()
sns.heatmap(corr_mat, square=True)
